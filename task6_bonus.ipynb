# %% [markdown]
# Task 6 - Bonus
# Gorentla Priyanka modified on 2/13/2023
# Analyzing Annual Enterprise Survey which is csvtest file

# %% [markdown]
# ### Loading and Displaying Details.csv file

# %%
import pandas as pd
dt = pd.read_csv('details.csv',
                  names=['Name','Sex','Weight'])
dt
# Out:
#         Name Sex  Weight
# 0   Priyanka   F   134.7
# 1      Vijay   M   186.8
# 2  Veerendra   M   170.3
# 3     Vikram   M   213.5
# 4      Rahul   M   230.6
# 5      Raasi   F   151.1

# %% [markdown]
# ### Loading and Displaying csvtest.csv file

# %%
import pandas as pd
dt = pd.read_csv('csvtest.csv')
dt
# Out:
#     Year Industryaggregation  Industrycode Variablecode  \
# 0   2021             Level 1         99999          H01
# 1   2021             Level 4         99999          H04
# 2   2021             Level 1         99999          H05
# 3   2021             Level 1         99999          H07
# 4   2021             Level 1         99999          H08
# 5   2021             Level 2         99999          H09
# 6   2021             Level 1         99999          H10
# 7   2021             Level 1         99999          H11
# 8   2021             Level 4         99999          H12
# 9   2021             Level 2         99999          H13
# 10  2021             Level 1         99999          H14
# 11  2021             Level 4         99999          H19
# 12  2021             Level 4         99999          H20
# 13  2021             Level 1         99999          H21
# 14  2021             Level 4         99999          H22
# 15  2021             Level 2         99999          H23
# ...

# %%
import pandas as pd
dt.head() // display first 5 rows from csv file
# Out:
#    Year Industryaggregation  Industrycode Variablecode  \
# 0  2021             Level 1         99999          H01
# 1  2021             Level 4         99999          H04
# 2  2021             Level 1         99999          H05
# 3  2021             Level 1         99999          H07
# 4  2021             Level 1         99999          H08
#
#                         Variablename       Variablecategory    Value
# 0                       Total income  Financial performance  757,504
# 1          Sales, government funding  Financial performance  674,890
# 2  Interest, dividends and donations  Financial performance   49,593
# 3               Non-operating income  Financial performance   33,020
# 4                  Total expenditure  Financial performance  654,404

# %%
import pandas as pd
dt.tail() # display last 5 rows from csv file
# Out:
#     Year Industryaggregation  Industrycode Variablecode  \
# 21  2021             Level 3         99999          H31
# 22  2021             Level 3         99999          H32
# 23  2021             Level 3         99999          H33
# 24  2021             Level 4         99999          H34
# 25  2021             Level 1         99999          H35
#
#                            Variablename    Variablecategory    Value
# 21  Shareholders funds or owners equity  Financial position  813,949
# 22                  Current liabilities  Financial position  933,093
# 23                    Other liabilities  Financial position  765,635
# 24      Total income per employee count    Financial ratios  400,900
# 25           Surplus per employee count    Financial ratios   54,700

# %% [markdown]
# ### Renaming columns

# %%
dt.columns = ['Year', 'Industry_aggregation', 'Industry_Code', 'Variable_Code','Varuable_Name','Variable_Category','Value']
dt.head()
# Out:
#    Year Industry_aggregation  Industry_Code Variable_Code  \
# 0  2021              Level 1          99999           H01
# 1  2021              Level 4          99999           H04
# 2  2021              Level 1          99999           H05
# 3  2021              Level 1          99999           H07
# 4  2021              Level 1          99999           H08
#
#                        Varuable_Name      Variable_Category    Value
# 0                       Total income  Financial performance  757,504
# 1          Sales, government funding  Financial performance  674,890
# 2  Interest, dividends and donations  Financial performance   49,593
# 3               Non-operating income  Financial performance   33,020
# 4                  Total expenditure  Financial performance  654,404

# %% [markdown]
# ### Calculating basic descriptive statistics

# %%
dt.describe()
# Out:
#          Year  Industry_Code
# count    26.0           26.0
# mean   2021.0        99999.0
# std       0.0            0.0
# min    2021.0        99999.0
# 25%    2021.0        99999.0
# 50%    2021.0        99999.0
# 75%    2021.0        99999.0
# max    2021.0        99999.0

# %% [markdown]
# ###  Generating histograms for all numeric columns

# %%
# %matplotlib inline

# %%
histogram = dt.hist()
